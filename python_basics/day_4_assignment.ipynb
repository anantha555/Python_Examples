# %% [markdown]
# **1.** **Fibonacci** **sequence**

# %%
def printFibSeries(nterms): 
    n1, n2 = 0, 1
    count = 0
    if nterms <= 0:
        print("Please enter a positive integer")
    elif nterms == 1:
        print("Fibonacci sequence upto",nterms,":")
        print(n1)
    else:
        print("Fibonacci sequence:")
        while count < nterms:
            print(n1)
            nth = n1 + n2
            n1 = n2
            n2 = nth
            count += 1

userValue = int(input("How many terms? "))
printFibSeries(userValue)
# Out:
# How many terms? 5
# Fibonacci sequence:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# **2. Binary file handlling**

# %%
file = open("binFile.txt","w")
file.write("I Love LetsUpgrade")
file.close()

# %%
file = open("binFile.txt","r")
someText = file.read()
print(someText) 
file.close()
# Out:
# I Love LetsUpgrade

# %%
file = open("binFile.txt","a")
file.write("\n\nWe all Love Phyton class at LU")
file.close()

# %%
with open("binFile.txt","r") as file:  
    someText = file.read()
    print(someText)
# Out:
# I Love LetsUpgrade
#
# We all Love Phyton class at LU

# %% [markdown]
# **3a. Static Movie recomender**
# method 1

# %%
import random
print("Movie type recommendation avalible are : \n 1. action \n 2. comedies \n 3. romantic \n 4. adventure")
userInput = input("Enter the movie type:")

movieTypeList =["action","comedies","romantic", "adventure"]
actionList =["Bloodshot","Bad Boys for Life","Mulan","Tenet","No Time to Die","Top Gun: Maverick","The King Man"]
comediesList =["Shazam!","Deadpool","3 Idiots","Tenet","Julayi","TMen in Black","Total Dhamaal"]
romanticList =["Jab Tak Hai Jaan","Tholi Prema","Bheeshma","Passengers","A Star is Born","Spider-Man: Homecoming"]
adventureList =["Thor: Ragnarok","Pirates of the Caribbean: On Stranger Tides","Logan","Puli","Wonder Woman","Avengers: Infinity War"]

def movieRecom(name):
  
  if name =='action':
    print(random.choices(actionList , k = 2)) 
  elif name =='comedies':
    print(random.choices(comediesList , k = 2)) 
  elif name =='romantic':
    print(random.choices(romanticList , k = 2)) 
  elif name =='adventure':
    print(random.choices(adventureList , k = 2)) 
  else:
    print(name ,"type not avliable!")

movieRecom(userInput)
# Out:
# Movie type recommendation avalible are :
#  1. action
#  2. comedies
#  3. romantic
#  4. adventure
# Enter the movie type:action
# ['No Time to Die', 'Bloodshot']

# %% [markdown]
# **3b. Static Movie recomender** method 2

# %%
import random
movieTypeList =["action","comedies","romantic", "adventure"]
actionList =["Bloodshot","Bad Boys for Life","Mulan","Tenet","No Time to Die","Top Gun: Maverick","The King Man"]
comediesList =["Shazam!","Deadpool","3 Idiots","Tenet","Julayi","TMen in Black","Total Dhamaal"]
romanticList =["Jab Tak Hai Jaan","Tholi Prema","Bheeshma","Passengers","A Star is Born","Spider-Man: Homecoming"]
adventureList =["Thor: Ragnarok","Pirates of the Caribbean: On Stranger Tides","Logan","Puli","Wonder Woman","Avengers: Infinity War"]



def callFun(yn):
    if yn == 'Y':
        print("\nMovie types:\n1. action\n2. comedies\n3. romantic\n4. adventure\n ")
        userInput = input("\nEnter the movie type:\n").lower()
        movieRecom(userInput)
        #return userInput
    else:
        print('\nthanks\n') 
        userInput = None
        movieRecom(userInput)
        #return userInput


def movieRecom(name):
  
  if name =='action':
    a = random.choices(actionList , k = 2)
    moviePrint(a,name)
    askagain() 
  elif name =='comedies':
    a = random.choices(comediesList , k = 2)
    moviePrint(a,name) 
    askagain()  
  elif name =='romantic':
    a = random.choices(romanticList , k = 2)
    moviePrint(a,name)
    askagain()  
  elif name =='adventure':
    a = random.choices(adventureList , k = 2)
    moviePrint(a,name)
    askagain() 
  elif name == None: 
    return 
  else:
    print(name ,"type not avliable!\n")
    askagain()


def askagain():
  userYN = input("would u like to try again ?(Y/N)\n").upper()
  callFun(userYN)

def moviePrint(b,n):
  print("\n")
  print(n,"type movies are:\n")
  print(*b, sep = "\n")
  print("\n")

userIn = callFun("Y")
movieRecom(userIn)
# Out:
# Movie types:
# 1. action
# 2. comedies
# 3. romantic
# 4. adventure
#
#
# Enter the movie type:
# Action
#
#
# action type movies are:
#
# Tenet
# Bloodshot
#
#
# would u like to try again ?(Y/N)
# y
#
# Movie types:
# 1. action
# 2. comedies
# 3. romantic
# 4. adventure
#
#
# Enter the movie type:
# comedieS
#
#
# comedies type movies are:
#
# Total Dhamaal
# Total Dhamaal
#
#
# would u like to try again ?(Y/N)
# N
#
# thanks
