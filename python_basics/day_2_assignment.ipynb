# %% [markdown]
# ### **1. List**

# %%
ak_list =[14,32,32,45,53,66,37,45,49]
print(ak_list.count(45))
print(ak_list.index(49))
ak_list.append(10)
print(ak_list)
ak_list.reverse()
print(ak_list)
ak_list.sort()
print(ak_list)
# Out:
# 2
# 8
# [14, 32, 32, 45, 53, 66, 37, 45, 49, 10]
# [10, 49, 45, 37, 66, 53, 45, 32, 32, 14]
# [10, 14, 32, 32, 37, 45, 45, 49, 53, 66]

# %% [markdown]
# ### **2. Dictionary**

# %%
ak_dict = {"a1":"Apple", "a2":"Nokia", "a3":"samsung"}
ak_dict
# Out:
# {'a1': 'Apple', 'a2': 'Nokia', 'a3': 'samsung'}

# %%
ak_dict.keys()
# Out:
# dict_keys(['a1', 'a2', 'a3'])

# %%
ak_dict.get("a1")
# Out:
# 'Apple'

# %%
ak_dict2 ={"b1":"Apple", "b2":"Nokia", "b3":"samsung"}
ak_dict.update(ak_dict2)
ak_dict
# Out:
# {'a1': 'Apple',
#  'a2': 'Nokia',
#  'a3': 'samsung',
#  'b1': 'Apple',
#  'b2': 'Nokia',
#  'b3': 'samsung'}

# %%
ak_dict.pop("a3")
ak_dict
# Out:
# {'a1': 'Apple', 'a2': 'Nokia', 'b1': 'Apple', 'b2': 'Nokia', 'b3': 'samsung'}

# %%
ak_dict.items()
# Out:
# dict_items([('a1', 'Apple'), ('a2', 'Nokia'), ('b1', 'Apple'), ('b2', 'Nokia'), ('b3', 'samsung')])

# %% [markdown]
# ### **3. Sets**

# %%
ak_set = {1,2,5,5,9,3,5,7,6,4,1,5,7}
ak_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %%
gn_set ={1,2,5,5,8,1,5,8,5,115,89,45,6,1}
gn_set
# Out:
# {1, 2, 5, 6, 8, 45, 89, 115}

# %%
ak_set.pop()
# Out:
# 1

# %%
ak_set
# Out:
# {2, 3, 4, 5, 6, 7, 9}

# %%
ak_set.difference(gn_set)
# Out:
# {3, 4, 7, 9}

# %%
ak_set.intersection(gn_set)
# Out:
# {2, 5, 6}

# %%
ak_set.remove(3)
ak_set
# Out:
# {2, 4, 5, 6, 7, 9}

# %%
ak_set.clear()
ak_set
# Out:
# set()

# %% [markdown]
# ### **4. Tuple**

# %%
ak_tup =(1,22,33,'aakk')

ak_tup
# Out:
# (1, 22, 33, 'aakk')

# %%
ak_tup.count(1)
# Out:
# 1

# %%
ak_tup.index('aakk')
# Out:
# 3

# %% [markdown]
# ### **5. String**

# %%
ak_str = 'anantha kumar'
ak_str
# Out:
# 'anantha kumar'

# %%
print(ak_str.capitalize())
# Out:
# Anantha kumar

# %%
ak_str.find("n")
# Out:
# 1

# %%
ak_str.isdigit()
# Out:
# False

# %%
ak_str.swapcase()
# Out:
# 'ANANTHA KUMAR'

# %%
ak_str.rfind("n")
# Out:
# 3
